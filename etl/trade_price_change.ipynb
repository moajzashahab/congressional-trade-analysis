# %% [markdown]
# This is for the QuiverQuant data set

# %%
#packages

import pandas as pd
import numpy as np
from pandas.tseries.offsets import BDay
import yfinance as yf
from tqdm import tqdm

# %%
#Import Data
trade_df = pd.read_excel('../data/quiverquant_congress_trading_all.xlsx')

# %%
trade_df['Traded'] = pd.to_datetime(trade_df['Traded'])

# %%
trade_df
# Out:
#       Ticker TickerType                                            Company  \
# 0       NVDA         ST                  NVIDIA CORPORATION - COMMON STOCK
# 1        NGL         ST  NGL ENERGY PARTNERS LP COMMON UNITS REPRESENTI...
# 2      BRK.B         ST           BERKSHIRE HATHAWAY INC. NEW COMMON STOCK
# 3         HD         ST                                   HOME DEPOT, INC.
# 4       TSLA         ST                         TESLA, INC. - COMMON STOCK
# ...      ...        ...                                                ...
# 48314    CAT        NaN                                  CATERPILLAR, INC.
# 48315     PG        NaN                           PROCTER & GAMBLE COMPANY
# 48316    KSU        NaN                               KANSAS CITY SOUTHERN
# 48317   EP$C        NaN                EL PASO CORPORATION PREFERRED STOCK
# 48318   EP$C        NaN                EL PASO CORPORATION PREFERRED STOCK
#
#           Traded Transaction      Trade_Size_USD Status  \
# 0     2024-11-01    Purchase    $1,001 - $15,000    NEW
# 1     2024-10-24        Sale  $50,001 - $100,000    NEW
# 2     2024-10-21    Purchase    $1,001 - $15,000    NEW
# 3     2024-10-21    Purchase    $1,001 - $15,000    NEW
# 4     2024-10-21    Purchase    $1,001 - $15,000    NEW
# ...          ...         ...                 ...    ...
# 48314 2012-07-26    Purchase    $1,001 - $15,000    NEW
# 48315 2012-07-24        Sale    $1,001 - $15,000    NEW
# 48316 2012-06-06    Purchase    $1,001 - $15,000    NEW
# 48317 2012-03-20        Sale    $1,001 - $15,000    NEW
# 48318 2012-02-27        Sale    $1,001 - $15,000    NEW
#
#                                    Subholding Description  \
# 0                                     IRA ONE         NaN
# 1       EQUITABLE ADVISORS INVESTMENT ACCOUNT         NaN
# 2                                         NaN         NaN
# 3                                         NaN         NaN
# 4                                         NaN         NaN
# ...                                       ...         ...
# 48314                  BROKERAGE #2 USAA 8425         NaN
# 48315                  BROKERAGE #2 USAA 8425         NaN
# 48316                                     NaN         NaN
# 48317                                     NaN         NaN
# 48318                                     NaN         NaN
#
#                              Name BioGuideID       Filed Party District  \
# 0                   Pete Sessions    S000250  2024-11-01     R     TX17
# 1                   Mark Dr Green    G000590  2024-10-29     R     TN07
# 2      Marjorie Taylor Mrs Greene    G000596  2024-10-22     R     GA14
# 3      Marjorie Taylor Mrs Greene    G000596  2024-10-22     R     GA14
# 4      Marjorie Taylor Mrs Greene    G000596  2024-10-22     R     GA14
# ...                           ...        ...         ...   ...      ...
# 48314         Ms. Tammy Duckworth    D000622  2014-07-08     D     IL08
# 48315         Ms. Tammy Duckworth    D000622  2014-07-08     D     IL08
# 48316       Mr. Alan S. Lowenthal    L000579  2014-05-15     D     CA47
# 48317       Mr. Alan S. Lowenthal    L000579  2014-05-15     D     CA47
# 48318       Mr. Alan S. Lowenthal    L000579  2014-05-15     D     CA47
#
#       Chamber Comments Quiver_Upload_Time  excess_return       State  \
# 0       House      NaN         2024-11-04       0.697227       Texas
# 1       House      NaN         2024-10-30      -3.609834   Tennessee
# 2       House      NaN         2024-10-22      -2.339083     Georgia
# 3       House      NaN         2024-10-22      -0.292208     Georgia
# 4       House      NaN         2024-10-22      13.334500     Georgia
# ...       ...      ...                ...            ...         ...
# 48314   House      NaN         2020-07-26      31.417039    Illinois
# 48315   House      NaN         2020-07-26    -169.316461    Illinois
# 48316   House      NaN         2020-07-26      89.238230  California
# 48317   House      NaN         2020-07-26            NaN  California
# 48318   House      NaN         2020-07-26            NaN  California
#
#       last_modified
# 0        2024-11-04
# 1        2024-10-30
# 2        2024-10-22
# 3        2024-10-22
# 4        2024-10-22
# ...             ...
# 48314    2023-11-16
# 48315    2023-11-16
# 48316    2023-11-16
# 48317    2023-11-16
# 48318    2023-11-16
#
# [48319 rows x 20 columns]

# %%
# trade_df_backup = trade_df
trade_df = trade_df_backup

# %%
# Clean invalid tickers
trade_df = trade_df[trade_df['Ticker'].str.match(r'^[A-Za-z]+$')]

# Reset index if necessary
trade_df.reset_index(drop=True, inplace=True)

# %%
def get_adjusted_closing_price(
    trade_df, 
    traded_date_col, 
    ticker_col, 
    offset_days=0, 
    new_col_name="Adjusted_Closing_Price"
):
    """
    Retrieves the closing price on a specified traded date with an optional offset in days.
    Adjusts to the nearest trading day if necessary, using yfinance to pull historical data.

    Parameters:
    - trade_df (pd.DataFrame): DataFrame with trade information.
    - traded_date_col (str): Name of the column in trade_df that contains the traded date.
    - ticker_col (str): Name of the column in trade_df that contains the ticker symbol.
    - offset_days (int): Number of days after the traded date to pull data for (can be negative).
    - new_col_name (str): Name of the new column to store the result in trade_df.

    Returns:
    - pd.DataFrame: trade_df with a new column containing the adjusted closing price.
    """

    # Ensure 'traded_date' column is in datetime format
    trade_df[traded_date_col] = pd.to_datetime(trade_df[traded_date_col])

    # Adjust the date by the given offset and snap to the nearest business day
    trade_df['target_date'] = trade_df[traded_date_col] + BDay(offset_days)
    trade_df['target_date'] = pd.to_datetime(trade_df['target_date'])
    trade_df['target_date'] = trade_df['target_date'].dt.tz_localize(None)

    # Initialize new column in trade_df with np.nan
    trade_df[new_col_name] = np.nan

    # Group by ticker to minimize API calls
    grouped = trade_df.groupby(ticker_col)

    for ticker, group in tqdm(grouped, desc="Processing tickers"):
        # Get all unique target dates for the ticker
        dates_needed = group['target_date'].unique()

        # Define start and end dates for historical data download
        start_date = min(dates_needed) - pd.Timedelta(days=5)
        end_date = max(dates_needed) + pd.Timedelta(days=5)

        # Download historical data for the ticker
        try:
            ticker_data = yf.download(
                ticker, 
                start=start_date.strftime('%Y-%m-%d'), 
                end=(end_date + pd.Timedelta(days=1)).strftime('%Y-%m-%d'),
                progress=False
            )
        except Exception as e:
            print(f"Failed to download data for ticker '{ticker}': {e}")
            trade_df.loc[group.index, new_col_name] = np.nan
            continue

        # Check if ticker_data is empty
        if ticker_data.empty:
            trade_df.loc[group.index, new_col_name] = np.nan
            continue

        # Prepare the historical data
        ticker_data = ticker_data.reset_index()
        ticker_data['Date'] = pd.to_datetime(ticker_data['Date'])
        ticker_data['Date'] = ticker_data['Date'].dt.tz_localize(None)
        ticker_data = ticker_data.set_index('Date')

        # Ensure the index is sorted
        ticker_data.sort_index(inplace=True)

        # Map the closing prices to the target dates
        def get_closing_price(date):
            # Ensure date is timezone-naive
            date = date.tz_localize(None)

            if date in ticker_data.index:
                return float(ticker_data.loc[date, 'Close'])
            else:
                # Find the previous available trading day
                previous_dates = ticker_data.index[ticker_data.index < date]
                if len(previous_dates) > 0:
                    closest_date = previous_dates[-1]
                    return float(ticker_data.loc[closest_date, 'Close'])
                else:
                    return np.nan  # np.nan is a float

        # Apply the function to each row in the group using .map()
        trade_df.loc[group.index, new_col_name] = group['target_date'].map(get_closing_price)

    # Drop the temporary 'target_date' column
    trade_df.drop(columns=['target_date'], inplace=True)

    # Ensure the 'price' column is of type float
    trade_df[new_col_name] = trade_df[new_col_name].astype(float)

    return trade_df

# %%
trade_df = get_adjusted_closing_price(trade_df,traded_date_col='Traded', ticker_col='Ticker',offset_days=0,new_col_name='price')
# Out:
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trade_df[traded_date_col] = pd.to_datetime(trade_df[traded_date_col])
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trade_df['target_date'] = trade_df[traded_date_col] + BDay(offset_days)
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trade_df['target_date'] = pd.to_datetime(trade_df['target_date'])
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trade_df['target_date'] = trade_df['target_date'].dt.tz_localize(None)
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trade_df[new_col_name] = np.nan
# Processing tickers:   0%|          | 0/3874 [00:00<?, ?it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers:   0%|          | 1/3874 [00:00<18:23,  3.51it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers:   0%|          | 2/3874 [00:00<16:59,  3.80it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers:   0%|          | 3/3874 [00:01<29:20,  2.20it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers:   0%|          | 4/3874 [00:01<20:22,  3.17it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers:   0%|          | 5/3874 [00:01<17:12,  3.75it/s]
# 1 Failed download:
# ['AAN']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2015-01-03 -> 2020-03-29) (Yahoo error = "Data doesn\'t exist for startDate = 1420261200, endDate = 1585454400")')
# Processing tickers:   0%|          | 6/3874 [00:02<38:09,  1.69it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers:   0%|          | 7/3874 [00:02<27:59,  2.30it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers:   0%|          | 8/3874 [00:03<22:36,  2.85it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers:   0%|          | 9/3874 [00:03<21:52,  2.94it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers:   0%|          | 10/3874 [00:03<18:23,  3.50it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers:   0%|          | 11/3874 [00:03<14:49,  4.34it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers:   0%|          | 12/3874 [00:03<12:27,  5.17it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers:   0%|          | 13/3874 [00:03<11:05,  5.80it/s]
# 1 Failed download:
# ['ABB']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Processing tickers:   0%|          | 14/3874 [00:04<23:21,  2.75it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers:   0%|          | 15/3874 [00:04<18:24,  3.49it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers:   0%|          | 16/3874 [00:04<17:48,  3.61it/s]
# 1 Failed download:
# ['ABC']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Processing tickers:   0%|          | 17/3874 [00:05<26:35,  2.42it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers:   0%|          | 18/3874 [00:05<21:56,  2.93it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:84: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[closest_date, 'Close'])
#
# 1 Failed download:
# ['ABDC']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Processing tickers:   1%|          | 20/3874 [00:06<25:20,  2.53it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers:   1%|          | 21/3874 [00:07<22:35,  2.84it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers:   1%|          | 23/3874 [00:07<16:19,  3.93it/s]
# 1 Failed download:
# ['ABMD']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Processing tickers:   1%|          | 24/3874 [00:08<30:16,  2.12it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers:   1%|          | 25/3874 [00:08<24:36,  2.61it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers:   1%|          | 26/3874 [00:08<20:10,  3.18it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers:   1%|          | 27/3874 [00:08<16:47,  3.82it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers:   1%|          | 28/3874 [00:09<15:47,  4.06it/s]
# 1 Failed download:
# ['ABX']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2014-10-17 -> 2018-10-28)')
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers:   1%|          | 30/3874 [00:09<11:36,  5.52it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers:   1%|          | 31/3874 [00:09<10:29,  6.11it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers:   1%|          | 32/3874 [00:09<09:33,  6.70it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
#
# 1 Failed download:
# ['ACC']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Processing tickers:   1%|          | 34/3874 [00:10<18:56,  3.38it/s]
# 1 Failed download:
# ['ACE']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2014-01-03 -> 2016-11-08) (Yahoo error = "Data doesn\'t exist for startDate = 1388725200, endDate = 1478581200")')
# Processing tickers:   1%|          | 35/3874 [00:11<25:06,  2.55it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers:   1%|          | 36/3874 [00:11<20:51,  3.07it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers:   1%|          | 37/3874 [00:11<18:18,  3.49it/s]
# 1 Failed download:
# ['ACGPF']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Processing tickers:   1%|          |
2024-10-21    Purchase    $1,001 - $15,000    NEW
# 3     2024-10-21    Purchase    $1,001 - $15,000    NEW
# 4     2024-10-21    Purchase    $1,001 - $15,000    NEW
# ...          ...         ...                 ...    ...
# 47720 2012-09-13    Purchase    $1,001 - $15,000    New
# 47721 2012-08-16        Sale    $1,001 - $15,000    NEW
# 47722 2012-07-26    Purchase    $1,001 - $15,000    NEW
# 47723 2012-07-24        Sale    $1,001 - $15,000    NEW
# 47724 2012-06-06    Purchase    $1,001 - $15,000    NEW
#
#                                    Subholding Description  \
# 0                                     IRA ONE         NaN
# 1       EQUITABLE ADVISORS INVESTMENT ACCOUNT         NaN
# 2                                         NaN         NaN
# 3                                         NaN         NaN
# 4                                         NaN         NaN
# ...                                       ...         ...
# 47720                                     NaN         NaN
# 47721                 BROKERAGE #1 - EDJ 2718         NaN
# 47722                  BROKERAGE #2 USAA 8425         NaN
# 47723                  BROKERAGE #2 USAA 8425         NaN
# 47724                                     NaN         NaN
#
#                              Name  ...       Filed Party District Chamber  \
# 0                   Pete Sessions  ...  2024-11-01     R     TX17   House
# 1                   Mark Dr Green  ...  2024-10-29     R     TN07   House
# 2      Marjorie Taylor Mrs Greene  ...  2024-10-22     R     GA14   House
# 3      Marjorie Taylor Mrs Greene  ...  2024-10-22     R     GA14   House
# 4      Marjorie Taylor Mrs Greene  ...  2024-10-22     R     GA14   House
# ...                           ...  ...         ...   ...      ...     ...
# 47720           Carper, Thomas R.  ...  2015-05-13     D      NaN  Senate
# 47721         Ms. Tammy Duckworth  ...  2014-07-08     D     IL08   House
# 47722         Ms. Tammy Duckworth  ...  2014-07-08     D     IL08   House
# 47723         Ms. Tammy Duckworth  ...  2014-07-08     D     IL08   House
# 47724       Mr. Alan S. Lowenthal  ...  2014-05-15     D     CA47   House
#
#       Comments Quiver_Upload_Time excess_return       State last_modified  \
# 0          NaN         2024-11-04      0.697227       Texas    2024-11-04
# 1          NaN         2024-10-30     -3.609834   Tennessee    2024-10-30
# 2          NaN         2024-10-22     -0.292208     Georgia    2024-10-22
# 3          NaN         2024-10-22     13.334500     Georgia    2024-10-22
# 4          NaN         2024-10-22      4.115725     Georgia    2024-10-22
# ...        ...                ...           ...         ...           ...
# 47720      NaN         2020-07-26   -336.952251    Delaware    2023-08-28
# 47721      NaN         2020-07-26   -156.969402    Illinois    2023-11-16
# 47722      NaN         2020-07-26     31.417039    Illinois    2023-11-16
# 47723      NaN         2020-07-26   -169.316461    Illinois    2023-11-16
# 47724      NaN         2020-07-26     89.238230  California    2023-11-16
#
#             price
# 0      135.399994
# 1        4.200000
# 2      406.399994
# 3      218.850006
# 4      286.850006
# ...           ...
# 47720   44.733368
# 47721   67.000000
# 47722   83.300003
# 47723   64.019997
# 47724         NaN
#
# [47725 rows x 21 columns]

# %%
trade_df = trade_df_test

# %%
# Drop rows where 'price' is NaN or None
trade_df = trade_df.dropna(subset=['price']).reset_index(drop=True)

# %%
trade_df.head()
# Out:
#   Ticker TickerType                                            Company  \
# 0   NVDA         ST                  NVIDIA CORPORATION - COMMON STOCK
# 1    NGL         ST  NGL ENERGY PARTNERS LP COMMON UNITS REPRESENTI...
# 2     HD         ST                                   HOME DEPOT, INC.
# 3   TSLA         ST                         TESLA, INC. - COMMON STOCK
# 4      V         ST                                          VISA INC.
#
#       Traded Transaction      Trade_Size_USD Status  \
# 0 2024-11-01    Purchase    $1,001 - $15,000    NEW
# 1 2024-10-24        Sale  $50,001 - $100,000    NEW
# 2 2024-10-21    Purchase    $1,001 - $15,000    NEW
# 3 2024-10-21    Purchase    $1,001 - $15,000    NEW
# 4 2024-10-21    Purchase    $1,001 - $15,000    NEW
#
#                                Subholding Description  \
# 0                                 IRA ONE         NaN
# 1   EQUITABLE ADVISORS INVESTMENT ACCOUNT         NaN
# 2                                     NaN         NaN
# 3                                     NaN         NaN
# 4                                     NaN         NaN
#
#                          Name  ...       Filed Party District Chamber  \
# 0               Pete Sessions  ...  2024-11-01     R     TX17   House
# 1               Mark Dr Green  ...  2024-10-29     R     TN07   House
# 2  Marjorie Taylor Mrs Greene  ...  2024-10-22     R     GA14   House
# 3  Marjorie Taylor Mrs Greene  ...  2024-10-22     R     GA14   House
# 4  Marjorie Taylor Mrs Greene  ...  2024-10-22     R     GA14   House
#
#   Comments Quiver_Upload_Time excess_return      State last_modified  \
# 0      NaN         2024-11-04      0.697227      Texas    2024-11-04
# 1      NaN         2024-10-30     -3.609834  Tennessee    2024-10-30
# 2      NaN         2024-10-22     -0.292208    Georgia    2024-10-22
# 3      NaN         2024-10-22     13.334500    Georgia    2024-10-22
# 4      NaN         2024-10-22      4.115725    Georgia    2024-10-22
#
#                                                price
# 0  Ticker
# NVDA    135.399994
# Name: 2024-11-01 00:...
# 1  Ticker
# NGL    4.2
# Name: 2024-10-24 00:00:00, d...
# 2  Ticker
# HD    406.399994
# Name: 2024-10-21 00:00...
# 3  Ticker
# TSLA    218.850006
# Name: 2024-10-21 00:...
# 4  Ticker
# V    286.850006
# Name: 2024-10-21 00:00:...
#
# [5 rows x 21 columns]

# %%
trade_df = get_adjusted_closing_price(trade_df,'Traded', 'Ticker',offset_days=365,new_col_name='price_plus_365')
# Out:
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trade_df[traded_date_col] = pd.to_datetime(trade_df[traded_date_col])
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trade_df['target_date'] = trade_df[traded_date_col] + BDay(offset_days)
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trade_df['target_date'] = pd.to_datetime(trade_df['target_date'])
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trade_df['target_date'] = trade_df['target_date'].dt.tz_localize(None)
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trade_df[new_col_name] = np.nan
# Processing tickers:   0%|          | 0/3874 [00:00<?, ?it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:84: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[closest_date, 'Close'])
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers:   0%|          | 1/3874 [00:00<13:47,  4.68it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:84: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[closest_date, 'Close'])
# Processing tickers:   0%|          | 2/3874 [00:00<12:51,  5.02it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:84: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[closest_date, 'Close'])
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers:   0%|          | 3/3874 [00:00<11:05,  5.82it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:84: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[closest_date, 'Close'])
# Processing tickers:   0%|          | 4/3874 [00:00<09:15,  6.96it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:84: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[closest_date, 'Close'])
# Processing tickers:   0%|          | 5/3874 [00:00<09:20,  6.90it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers:   0%|          | 6/3874 [00:00<08:21,  7.71it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers:   0%|          | 7/3874 [00:00<07:52,  8.18it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:84: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[closest_date, 'Close'])
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers:   0%|          | 8/3874 [00:01<07:57,  8.10it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:84: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[closest_date, 'Close'])
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers:   0%|          | 9/3874 [00:01<11:29,  5.61it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:84: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[closest_date, 'Close'])
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers:   0%|          | 10/3874 [00:01<10:52,  5.93it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:84: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[closest_date, 'Close'])
# Processing tickers:   0%|          | 12/3874 [00:01<08:32,  7.53it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers:   0%|          | 13/3874 [00:01<08:24,  7.65it/s]
# 1 Failed download:
# ['ABB']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Processing tickers:   0%|          | 14/3874 [00:03<28:54,  2.23it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:84: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[closest_date, 'Close'])
# Processing tickers:   0%|          | 15/3874 [00:03<22:55,  2.81it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:84: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[closest_date, 'Close'])
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers:   0%|          | 16/3874 [00:03<20:31,  3.13it/s]
# 1 Failed download:
# ['ABC']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Processing tickers:   0%|          | 17/3874 [00:04<30:22,  2.12it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:84: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[closest_date, 'Close'])
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers:   0%|          | 18/3874 [00:04<24:49,  2.59it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:84: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[closest_date, 'Close'])
#
# 1 Failed download:
# ['ABDC']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Processing tickers:   1%|          | 20/3874 [00:05<27:29,  2.34it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:84: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[closest_date, 'Close'])
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers:   1%|          | 21/3874 [00:05<23:47,  2.70it/s]
# 1 Failed download:
# ['ABG']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2025-06-13 -> 2025-06-24) (Yahoo error = "Data doesn\'t exist for startDate = 1749787200, endDate = 1750737600")')
# Processing tickers:   1%|          | 22/3874 [00:06<29:22,  2.19it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers:   1%|          | 23/3874 [00:06<25:16,  2.54it/s]
# 1 Failed download:
# ['ABMD']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Processing tickers:   1%|          |
']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Processing tickers:  99%|█████████▉| 3842/3874 [19:45<00:12,  2.61it/s]
# 1 Failed download:
# ['YNDX']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Processing tickers:  99%|█████████▉| 3843/3874 [19:45<00:16,  1.90it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:84: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[closest_date, 'Close'])
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers:  99%|█████████▉| 3845/3874 [19:46<00:10,  2.90it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers:  99%|█████████▉| 3847/3874 [19:46<00:06,  4.09it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:84: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[closest_date, 'Close'])
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers:  99%|█████████▉| 3849/3874 [19:46<00:05,  4.55it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:84: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[closest_date, 'Close'])
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers:  99%|█████████▉| 3850/3874 [19:46<00:04,  4.85it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:84: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[closest_date, 'Close'])
# Processing tickers:  99%|█████████▉| 3852/3874 [19:47<00:03,  6.17it/s]
# 1 Failed download:
# ['ZAYO']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Processing tickers:  99%|█████████▉| 3853/3874 [19:47<00:06,  3.40it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers:  99%|█████████▉| 3854/3874 [19:48<00:05,  3.43it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:84: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[closest_date, 'Close'])
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers: 100%|█████████▉| 3855/3874 [19:48<00:05,  3.65it/s]
# 1 Failed download:
# ['ZEN']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Processing tickers: 100%|█████████▉| 3856/3874 [19:48<00:06,  2.67it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:84: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[closest_date, 'Close'])
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers: 100%|█████████▉| 3858/3874 [19:49<00:04,  3.93it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers: 100%|█████████▉| 3860/3874 [19:49<00:03,  4.60it/s]
# 1 Failed download:
# ['ZIOP']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Processing tickers: 100%|█████████▉| 3861/3874 [19:50<00:04,  2.89it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:84: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[closest_date, 'Close'])
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:84: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[closest_date, 'Close'])
# Processing tickers: 100%|█████████▉| 3863/3874 [19:50<00:02,  3.93it/s]
# 1 Failed download:
# ['ZMH']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2015-07-23 -> 2015-10-19)')
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers: 100%|█████████▉| 3865/3874 [19:50<00:01,  5.14it/s]
# 1 Failed download:
# ['ZN']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Processing tickers: 100%|█████████▉| 3866/3874 [19:51<00:02,  3.29it/s]
# 1 Failed download:
# ['ZNGA']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Processing tickers: 100%|█████████▉| 3867/3874 [19:52<00:02,  2.62it/s]
# 1 Failed download:
# ['ZOOM']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Processing tickers: 100%|█████████▉| 3868/3874 [19:52<00:02,  2.16it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:84: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[closest_date, 'Close'])
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers: 100%|█████████▉| 3869/3874 [19:52<00:01,  2.66it/s]
# 1 Failed download:
# ['ZTO']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2025-09-04 -> 2025-09-16) (Yahoo error = "Data doesn\'t exist for startDate = 1756958400, endDate = 1757995200")')
# Processing tickers: 100%|█████████▉| 3870/3874 [19:53<00:01,  2.19it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:84: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[closest_date, 'Close'])
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers: 100%|█████████▉| 3871/3874 [19:53<00:01,  2.56it/s]
# 1 Failed download:
# ['ZU']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Processing tickers: 100%|█████████▉| 3872/3874 [19:54<00:01,  1.95it/s]C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:84: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[closest_date, 'Close'])
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:78: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   return float(ticker_data.loc[date, 'Close'])
# Processing tickers: 100%|██████████| 3874/3874 [19:54<00:00,  3.24it/s]
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trade_df.drop(columns=['target_date'], inplace=True)
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\2759056213.py:95: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   trade_df[new_col_name] = trade_df[new_col_name].astype(float)

# %%
trade_df_backup = trade_df

# %%
# Drop rows where 'price' is NaN or None
trade_df = trade_df.dropna(subset=['price']).reset_index(drop=True)

# %%
trade_df
# Out:
#       Ticker TickerType                                            Company  \
# 0       NVDA         ST                  NVIDIA CORPORATION - COMMON STOCK
# 1        NGL         ST  NGL ENERGY PARTNERS LP COMMON UNITS REPRESENTI...
# 2         HD         ST                                   HOME DEPOT, INC.
# 3       TSLA         ST                         TESLA, INC. - COMMON STOCK
# 4          V         ST                                          VISA INC.
# ...      ...        ...                                                ...
# 41312    LMT        NaN                        LOCKHEED MARTIN CORPORATION
# 41313     DD      Stock        E. I. du Pont de Nemours and Company (NYSE)
# 41314     PG        NaN                           PROCTER & GAMBLE COMPANY
# 41315    CAT        NaN                                  CATERPILLAR, INC.
# 41316     PG        NaN                           PROCTER & GAMBLE COMPANY
#
#           Traded Transaction      Trade_Size_USD Status  \
# 0     2024-11-01    Purchase    $1,001 - $15,000    NEW
# 1     2024-10-24        Sale  $50,001 - $100,000    NEW
# 2     2024-10-21    Purchase    $1,001 - $15,000    NEW
# 3     2024-10-21    Purchase    $1,001 - $15,000    NEW
# 4     2024-10-21    Purchase    $1,001 - $15,000    NEW
# ...          ...         ...                 ...    ...
# 41312 2012-11-13        Sale    $1,001 - $15,000    NEW
# 41313 2012-09-13    Purchase    $1,001 - $15,000    New
# 41314 2012-08-16        Sale    $1,001 - $15,000    NEW
# 41315 2012-07-26    Purchase    $1,001 - $15,000    NEW
# 41316 2012-07-24        Sale    $1,001 - $15,000    NEW
#
#                                    Subholding Description  \
# 0                                     IRA ONE         NaN
# 1       EQUITABLE ADVISORS INVESTMENT ACCOUNT         NaN
# 2                                         NaN         NaN
# 3                                         NaN         NaN
# 4                                         NaN         NaN
# ...                                       ...         ...
# 41312                 BROKERAGE #1 - EDJ 2718         NaN
# 41313                                     NaN         NaN
# 41314                 BROKERAGE #1 - EDJ 2718         NaN
# 41315                  BROKERAGE #2 USAA 8425         NaN
# 41316                  BROKERAGE #2 USAA 8425         NaN
#
#                              Name  ... Party District Chamber Comments  \
# 0                   Pete Sessions  ...     R     TX17   House      NaN
# 1                   Mark Dr Green  ...     R     TN07   House      NaN
# 2      Marjorie Taylor Mrs Greene  ...     R     GA14   House      NaN
# 3      Marjorie Taylor Mrs Greene  ...     R     GA14   House      NaN
# 4      Marjorie Taylor Mrs Greene  ...     R     GA14   House      NaN
# ...                           ...  ...   ...      ...     ...      ...
# 41312         Ms. Tammy Duckworth  ...     D     IL08   House      NaN
# 41313           Carper, Thomas R.  ...     D      NaN  Senate      NaN
# 41314         Ms. Tammy Duckworth  ...     D     IL08   House      NaN
# 41315         Ms. Tammy Duckworth  ...     D     IL08   House      NaN
# 41316         Ms. Tammy Duckworth  ...     D     IL08   House      NaN
#
#       Quiver_Upload_Time excess_return      State  last_modified       price  \
# 0             2024-11-04      0.697227      Texas     2024-11-04  135.399994
# 1             2024-10-30     -3.609834  Tennessee     2024-10-30    4.200000
# 2             2024-10-22     -0.292208    Georgia     2024-10-22  406.399994
# 3             2024-10-22     13.334500    Georgia     2024-10-22  218.850006
# 4             2024-10-22      4.115725    Georgia     2024-10-22  286.850006
# ...                  ...           ...        ...            ...         ...
# 41312         2020-07-26    187.052900   Illinois     2023-11-16   90.180000
# 41313         2020-07-26   -336.952251   Delaware     2023-08-28   44.733368
# 41314         2020-07-26   -156.969402   Illinois     2023-11-16   67.000000
# 41315         2020-07-26     31.417039   Illinois     2023-11-16   83.300003
# 41316         2020-07-26   -169.316461   Illinois     2023-11-16   64.019997
#
#       price_plus_365
# 0         138.250000
# 1           4.820000
# 2         429.130005
# 3         345.160004
# 4         315.079987
# ...              ...
# 41312     156.649994
# 41313      64.886871
# 41314      80.419998
# 41315      87.540001
# 41316      80.910004
#
# [41317 rows x 22 columns]

# %%
# Store trade df
trade_df.to_excel('../data/qq_trade_df.xlsx',index=False)

# %%
# Recover trade df
trade_df = pd.read_excel('../data/qq_trade_df.xlsx')

# %%
trade_df['price_plus_365']
# Out:
# 0        138.250000
# 1          4.820000
# 2        429.130005
# 3        345.160004
# 4        315.079987
#             ...
# 41312    156.649994
# 41313     64.886871
# 41314     80.419998
# 41315     87.540001
# 41316     80.910004
# Name: price_plus_365, Length: 41317, dtype: float64

# %%
trade_df['price_change']=trade_df['price_plus_365']-trade_df['price']

# %%
trade_df
# Out:
#       Ticker TickerType                                            Company  \
# 0       NVDA         ST                  NVIDIA CORPORATION - COMMON STOCK
# 1        NGL         ST  NGL ENERGY PARTNERS LP COMMON UNITS REPRESENTI...
# 2         HD         ST                                   HOME DEPOT, INC.
# 3       TSLA         ST                         TESLA, INC. - COMMON STOCK
# 4          V         ST                                          VISA INC.
# ...      ...        ...                                                ...
# 41312    LMT        NaN                        LOCKHEED MARTIN CORPORATION
# 41313     DD      Stock        E. I. du Pont de Nemours and Company (NYSE)
# 41314     PG        NaN                           PROCTER & GAMBLE COMPANY
# 41315    CAT        NaN                                  CATERPILLAR, INC.
# 41316     PG        NaN                           PROCTER & GAMBLE COMPANY
#
#           Traded Transaction      Trade_Size_USD Status  \
# 0     2024-11-01    Purchase    $1,001 - $15,000    NEW
# 1     2024-10-24        Sale  $50,001 - $100,000    NEW
# 2     2024-10-21    Purchase    $1,001 - $15,000    NEW
# 3     2024-10-21    Purchase    $1,001 - $15,000    NEW
# 4     2024-10-21    Purchase    $1,001 - $15,000    NEW
# ...          ...         ...                 ...    ...
# 41312 2012-11-13        Sale    $1,001 - $15,000    NEW
# 41313 2012-09-13    Purchase    $1,001 - $15,000    New
# 41314 2012-08-16        Sale    $1,001 - $15,000    NEW
# 41315 2012-07-26    Purchase    $1,001 - $15,000    NEW
# 41316 2012-07-24        Sale    $1,001 - $15,000    NEW
#
#                                    Subholding Description  \
# 0                                     IRA ONE         NaN
# 1       EQUITABLE ADVISORS INVESTMENT ACCOUNT         NaN
# 2                                         NaN         NaN
# 3                                         NaN         NaN
# 4                                         NaN         NaN
# ...                                       ...         ...
# 41312                 BROKERAGE #1 - EDJ 2718         NaN
# 41313                                     NaN         NaN
# 41314                 BROKERAGE #1 - EDJ 2718         NaN
# 41315                  BROKERAGE #2 USAA 8425         NaN
# 41316                  BROKERAGE #2 USAA 8425         NaN
#
#                              Name  ... District Chamber Comments  \
# 0                   Pete Sessions  ...     TX17   House      NaN
# 1                   Mark Dr Green  ...     TN07   House      NaN
# 2      Marjorie Taylor Mrs Greene  ...     GA14   House      NaN
# 3      Marjorie Taylor Mrs Greene  ...     GA14   House      NaN
# 4      Marjorie Taylor Mrs Greene  ...     GA14   House      NaN
# ...                           ...  ...      ...     ...      ...
# 41312         Ms. Tammy Duckworth  ...     IL08   House      NaN
# 41313           Carper, Thomas R.  ...      NaN  Senate      NaN
# 41314         Ms. Tammy Duckworth  ...     IL08   House      NaN
# 41315         Ms. Tammy Duckworth  ...     IL08   House      NaN
# 41316         Ms. Tammy Duckworth  ...     IL08   House      NaN
#
#       Quiver_Upload_Time excess_return      State last_modified       price  \
# 0             2024-11-04      0.697227      Texas    2024-11-04  135.399994
# 1             2024-10-30     -3.609834  Tennessee    2024-10-30    4.200000
# 2             2024-10-22     -0.292208    Georgia    2024-10-22  406.399994
# 3             2024-10-22     13.334500    Georgia    2024-10-22  218.850006
# 4             2024-10-22      4.115725    Georgia    2024-10-22  286.850006
# ...                  ...           ...        ...           ...         ...
# 41312         2020-07-26    187.052900   Illinois    2023-11-16   90.180000
# 41313         2020-07-26   -336.952251   Delaware    2023-08-28   44.733368
# 41314         2020-07-26   -156.969402   Illinois    2023-11-16   67.000000
# 41315         2020-07-26     31.417039   Illinois    2023-11-16   83.300003
# 41316         2020-07-26   -169.316461   Illinois    2023-11-16   64.019997
#
#       price_plus_365 price_change
# 0         138.250000     2.850006
# 1           4.820000     0.620000
# 2         429.130005    22.730011
# 3         345.160004   126.309998
# 4         315.079987    28.229980
# ...              ...          ...
# 41312     156.649994    66.469994
# 41313      64.886871    20.153503
# 41314      80.419998    13.419998
# 41315      87.540001     4.239998
# 41316      80.910004    16.890007
#
# [41317 rows x 23 columns]

# %%
# Store trade df
trade_df.to_excel('../data/qq_trade_df.xlsx',index=False)

# %%
# Restore trade df
trade_df = pd.read_excel('../data/qq_trade_df.xlsx')
trade_df.head()
# Out:
#   Ticker TickerType                                            Company  \
# 0   NVDA         ST                  NVIDIA CORPORATION - COMMON STOCK
# 1    NGL         ST  NGL ENERGY PARTNERS LP COMMON UNITS REPRESENTI...
# 2     HD         ST                                   HOME DEPOT, INC.
# 3   TSLA         ST                         TESLA, INC. - COMMON STOCK
# 4      V         ST                                          VISA INC.
#
#       Traded Transaction      Trade_Size_USD Status  \
# 0 2024-11-01    Purchase    $1,001 - $15,000    NEW
# 1 2024-10-24        Sale  $50,001 - $100,000    NEW
# 2 2024-10-21    Purchase    $1,001 - $15,000    NEW
# 3 2024-10-21    Purchase    $1,001 - $15,000    NEW
# 4 2024-10-21    Purchase    $1,001 - $15,000    NEW
#
#                                Subholding Description  \
# 0                                 IRA ONE         NaN
# 1   EQUITABLE ADVISORS INVESTMENT ACCOUNT         NaN
# 2                                     NaN         NaN
# 3                                     NaN         NaN
# 4                                     NaN         NaN
#
#                          Name  ... District Chamber Comments  \
# 0               Pete Sessions  ...     TX17   House      NaN
# 1               Mark Dr Green  ...     TN07   House      NaN
# 2  Marjorie Taylor Mrs Greene  ...     GA14   House      NaN
# 3  Marjorie Taylor Mrs Greene  ...     GA14   House      NaN
# 4  Marjorie Taylor Mrs Greene  ...     GA14   House      NaN
#
#   Quiver_Upload_Time excess_return      State last_modified       price  \
# 0         2024-11-04      0.697227      Texas    2024-11-04  135.399994
# 1         2024-10-30     -3.609834  Tennessee    2024-10-30    4.200000
# 2         2024-10-22     -0.292208    Georgia    2024-10-22  406.399994
# 3         2024-10-22     13.334500    Georgia    2024-10-22  218.850006
# 4         2024-10-22      4.115725    Georgia    2024-10-22  286.850006
#
#   price_plus_365 price_change
# 0     147.452301    12.052307
# 1       4.150000    -0.050000
# 2     404.345001    -2.054993
# 3     317.140015    98.290009
# 4     310.769989    23.919983
#
# [5 rows x 23 columns]

# %%
ticker_df = pd.read_csv('../data/ticker_sector_data.csv')
ticker_df.head()
# Out:
#   Symbol                                               Name        Country  \
# 0      A             Agilent Technologies Inc. Common Stock  United States
# 1     AA                    Alcoa Corporation Common Stock   United States
# 2   AACG   ATA Creativity Global American Depositary Shares          China
# 3   AACT  Ares Acquisition Corporation II Class A Ordina...            NaN
# 4   AADI                  Aadi Bioscience Inc. Common Stock  United States
#
#    IPO Year   Volume       Sector  \
# 0    1999.0   950947  Industrials
# 1    2016.0  1785157  Industrials
# 2    2008.0    24438  Real Estate
# 3    2023.0    95056      Finance
# 4       NaN    44392  Health Care
#
#                                            Industry
# 0  Biotechnology: Laboratory Analytical Instruments
# 1                                          Aluminum
# 2                           Other Consumer Services
# 3                                      Blank Checks
# 4        Biotechnology: Pharmaceutical Preparations

# %%
merged_trades = pd.merge(trade_df, ticker_df[['Symbol','Sector','Industry']], left_on='Ticker', right_on='Symbol', how='left')
merged_trades
# Out:
#       Ticker TickerType                                            Company  \
# 0       NVDA         ST                  NVIDIA CORPORATION - COMMON STOCK
# 1        NGL         ST  NGL ENERGY PARTNERS LP COMMON UNITS REPRESENTI...
# 2         HD         ST                                   HOME DEPOT, INC.
# 3       TSLA         ST                         TESLA, INC. - COMMON STOCK
# 4          V         ST                                          VISA INC.
# ...      ...        ...                                                ...
# 41312    LMT        NaN                        LOCKHEED MARTIN CORPORATION
# 41313     DD      Stock        E. I. du Pont de Nemours and Company (NYSE)
# 41314     PG        NaN                           PROCTER & GAMBLE COMPANY
# 41315    CAT        NaN                                  CATERPILLAR, INC.
# 41316     PG        NaN                           PROCTER & GAMBLE COMPANY
#
#           Traded Transaction      Trade_Size_USD Status  \
# 0     2024-11-01    Purchase    $1,001 - $15,000    NEW
# 1     2024-10-24        Sale  $50,001 - $100,000    NEW
# 2     2024-10-21    Purchase    $1,001 - $15,000    NEW
# 3     2024-10-21    Purchase    $1,001 - $15,000    NEW
# 4     2024-10-21    Purchase    $1,001 - $15,000    NEW
# ...          ...         ...                 ...    ...
# 41312 2012-11-13        Sale    $1,001 - $15,000    NEW
# 41313 2012-09-13    Purchase    $1,001 - $15,000    New
# 41314 2012-08-16        Sale    $1,001 - $15,000    NEW
# 41315 2012-07-26    Purchase    $1,001 - $15,000    NEW
# 41316 2012-07-24        Sale    $1,001 - $15,000    NEW
#
#                                    Subholding Description  \
# 0                                     IRA ONE         NaN
# 1       EQUITABLE ADVISORS INVESTMENT ACCOUNT         NaN
# 2                                         NaN         NaN
# 3                                         NaN         NaN
# 4                                         NaN         NaN
# ...                                       ...         ...
# 41312                 BROKERAGE #1 - EDJ 2718         NaN
# 41313                                     NaN         NaN
# 41314                 BROKERAGE #1 - EDJ 2718         NaN
# 41315                  BROKERAGE #2 USAA 8425         NaN
# 41316                  BROKERAGE #2 USAA 8425         NaN
#
#                              Name  ... Quiver_Upload_Time excess_return  \
# 0                   Pete Sessions  ...         2024-11-04      0.697227
# 1                   Mark Dr Green  ...         2024-10-30     -3.609834
# 2      Marjorie Taylor Mrs Greene  ...         2024-10-22     -0.292208
# 3      Marjorie Taylor Mrs Greene  ...         2024-10-22     13.334500
# 4      Marjorie Taylor Mrs Greene  ...         2024-10-22      4.115725
# ...                           ...  ...                ...           ...
# 41312         Ms. Tammy Duckworth  ...         2020-07-26    187.052900
# 41313           Carper, Thomas R.  ...         2020-07-26   -336.952251
# 41314         Ms. Tammy Duckworth  ...         2020-07-26   -156.969402
# 41315         Ms. Tammy Duckworth  ...         2020-07-26     31.417039
# 41316         Ms. Tammy Duckworth  ...         2020-07-26   -169.316461
#
#            State last_modified       price price_plus_365 price_change  \
# 0          Texas    2024-11-04  135.399994     138.250000     2.850006
# 1      Tennessee    2024-10-30    4.200000       4.820000     0.620000
# 2        Georgia    2024-10-22  406.399994     429.130005    22.730011
# 3        Georgia    2024-10-22  218.850006     345.160004   126.309998
# 4        Georgia    2024-10-22  286.850006     315.079987    28.229980
# ...          ...           ...         ...            ...          ...
# 41312   Illinois    2023-11-16   90.180000     156.649994    66.469994
# 41313   Delaware    2023-08-28   44.733368      64.886871    20.153503
# 41314   Illinois    2023-11-16   67.000000      80.419998    13.419998
# 41315   Illinois    2023-11-16   83.300003      87.540001     4.239998
# 41316   Illinois    2023-11-16   64.019997      80.910004    16.890007
#
#        Symbol                  Sector                          Industry
# 0        NVDA              Technology                    Semiconductors
# 1         NGL               Utilities          Natural Gas Distribution
# 2          HD  Consumer Discretionary        RETAIL: Building Materials
# 3        TSLA  Consumer Discretionary                Auto Manufacturing
# 4           V  Consumer Discretionary                 Business Services
# ...       ...                     ...                               ...
# 41312     LMT             Industrials     Military/Government/Technical
# 41313      DD             Industrials                   Major Chemicals
# 41314      PG  Consumer Discretionary           Package Goods/Cosmetics
# 41315     CAT             Industrials  Construction/Ag Equipment/Trucks
# 41316      PG  Consumer Discretionary           Package Goods/Cosmetics
#
# [41317 rows x 26 columns]

# %%
# Download data
start_date = '2012-01-01'
end_date = '2024-11-28'
sp500_data = yf.download('^GSPC', start=start_date, end=end_date)
sp500_data.columns = ['_'.join(col) for col in sp500_data.columns]
sp500_data.reset_index(inplace=True)

# Rename columns
sp500_data.columns = [
    'Date',
    'Adj Close',
    'Close',
    'High',
    'Low',
    'Open',
    'Volume'
    ]

# Ensure 'Date' is of datetime type
sp500_data['Date'] = pd.to_datetime(sp500_data['Date'])

# Create 'Date_Plus_365' by adding 365 days
sp500_data['Date_Plus_365'] = sp500_data['Date'] + pd.Timedelta(days=365)

# Sort dataframes by 'Date'
sp500_data.sort_values('Date', inplace=True)

# Prepare future data
future_data = sp500_data[['Date', 'Close']]
future_data.rename(columns={'Date': 'Future_Date', 'Close': 'Future_Close'}, inplace=True)

# Merge using merge_asof with suffixes to prevent overlapping column names
merged_data = pd.merge_asof(
    sp500_data,
    future_data,
    left_on='Date_Plus_365',
    right_on='Future_Date',
    direction='forward',
    suffixes=('', '_future')  # This prevents multi-level columns
)

# Drop rows without future data
merged_data.dropna(inplace=True)

# Calculate percentage change
merged_data['S&P500 Change (%)'] = ((merged_data['Future_Close'] - merged_data['Close']) / merged_data['Close']) * 100

# Prepare results DataFrame by selecting only necessary columns
sp500_df = merged_data[['Date', 'Date_Plus_365', 'S&P500 Change (%)']].copy()
sp500_df['Date_Plus_365'] = merged_data['Future_Date'] # Use 'Future_Date' after merge
sp500_df['S&P500 Change (%)'] = sp500_df['S&P500 Change (%)'].round(2)

# Display results
print(sp500_df)
# Out:
# [*********************100%***********************]  1 of 1 completed
#                           Date             Date_Plus_365  S&P500 Change (%)
# 0    2012-01-03 00:00:00+00:00 2013-01-02 00:00:00+00:00              14.51
# 1    2012-01-04 00:00:00+00:00 2013-01-03 00:00:00+00:00              14.25
# 2    2012-01-05 00:00:00+00:00 2013-01-04 00:00:00+00:00              14.47
# 3    2012-01-06 00:00:00+00:00 2013-01-07 00:00:00+00:00              14.41
# 4    2012-01-09 00:00:00+00:00 2013-01-08 00:00:00+00:00              13.78
# ...                        ...                       ...                ...
# 2991 2023-11-21 00:00:00+00:00 2024-11-20 00:00:00+00:00              30.38
# 2992 2023-11-22 00:00:00+00:00 2024-11-21 00:00:00+00:00              30.55
# 2993 2023-11-24 00:00:00+00:00 2024-11-25 00:00:00+00:00              31.32
# 2994 2023-11-27 00:00:00+00:00 2024-11-26 00:00:00+00:00              32.33
# 2995 2023-11-28 00:00:00+00:00 2024-11-27 00:00:00+00:00              31.70
#
# [2996 rows x 3 columns]
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\1723836728.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   future_data.rename(columns={'Date': 'Future_Date', 'Close': 'Future_Close'}, inplace=True)

# %%
sp500_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2996 entries, 0 to 2995
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               2996 non-null   datetime64[ns, UTC]
#  1   Date_Plus_365      2996 non-null   datetime64[ns, UTC]
#  2   S&P500 Change (%)  2996 non-null   float64
# dtypes: datetime64[ns, UTC](2), float64(1)
# memory usage: 93.6 KB

# %%
trades_sub = merged_trades
trades_sub['Traded'] = pd.to_datetime(trades_sub['Traded'])
trades_sub['Traded'] = pd.to_datetime(trades_sub['Traded'], utc=True)
merged_trades = pd.merge(merged_trades, sp500_df, left_on='Traded', right_on='Date', how='left')
merged_trades
# Out:
#       Ticker TickerType                                            Company  \
# 0       NVDA         ST                  NVIDIA CORPORATION - COMMON STOCK
# 1        NGL         ST  NGL ENERGY PARTNERS LP COMMON UNITS REPRESENTI...
# 2         HD         ST                                   HOME DEPOT, INC.
# 3       TSLA         ST                         TESLA, INC. - COMMON STOCK
# 4          V         ST                                          VISA INC.
# ...      ...        ...                                                ...
# 41312    LMT        NaN                        LOCKHEED MARTIN CORPORATION
# 41313     DD      Stock        E. I. du Pont de Nemours and Company (NYSE)
# 41314     PG        NaN                           PROCTER & GAMBLE COMPANY
# 41315    CAT        NaN                                  CATERPILLAR, INC.
# 41316     PG        NaN                           PROCTER & GAMBLE COMPANY
#
#                          Traded Transaction      Trade_Size_USD Status  \
# 0     2024-11-01 00:00:00+00:00    Purchase    $1,001 - $15,000    NEW
# 1     2024-10-24 00:00:00+00:00        Sale  $50,001 - $100,000    NEW
# 2     2024-10-21 00:00:00+00:00    Purchase    $1,001 - $15,000    NEW
# 3     2024-10-21 00:00:00+00:00    Purchase    $1,001 - $15,000    NEW
# 4     2024-10-21 00:00:00+00:00    Purchase    $1,001 - $15,000    NEW
# ...                         ...         ...                 ...    ...
# 41312 2012-11-13 00:00:00+00:00        Sale    $1,001 - $15,000    NEW
# 41313 2012-09-13 00:00:00+00:00    Purchase    $1,001 - $15,000    New
# 41314 2012-08-16 00:00:00+00:00        Sale    $1,001 - $15,000    NEW
# 41315 2012-07-26 00:00:00+00:00    Purchase    $1,001 - $15,000    NEW
# 41316 2012-07-24 00:00:00+00:00        Sale    $1,001 - $15,000    NEW
#
#                                    Subholding Description  \
# 0                                     IRA ONE         NaN
# 1       EQUITABLE ADVISORS INVESTMENT ACCOUNT         NaN
# 2                                         NaN         NaN
# 3                                         NaN         NaN
# 4                                         NaN         NaN
# ...                                       ...         ...
# 41312                 BROKERAGE #1 - EDJ 2718         NaN
# 41313                                     NaN         NaN
# 41314                 BROKERAGE #1 - EDJ 2718         NaN
# 41315                  BROKERAGE #2 USAA 8425         NaN
# 41316                  BROKERAGE #2 USAA 8425         NaN
#
#                              Name  ... last_modified       price  \
# 0                   Pete Sessions  ...    2024-11-04  135.399994
# 1                   Mark Dr Green  ...    2024-10-30    4.200000
# 2      Marjorie Taylor Mrs Greene  ...    2024-10-22  406.399994
# 3      Marjorie Taylor Mrs Greene  ...    2024-10-22  218.850006
# 4      Marjorie Taylor Mrs Greene  ...    2024-10-22  286.850006
# ...                           ...  ...           ...         ...
# 41312         Ms. Tammy Duckworth  ...    2023-11-16   90.180000
# 41313           Carper, Thomas R.  ...    2023-08-28   44.733368
# 41314         Ms. Tammy Duckworth  ...    2023-11-16   67.000000
# 41315         Ms. Tammy Duckworth  ...    2023-11-16   83.300003
# 41316         Ms. Tammy Duckworth  ...    2023-11-16   64.019997
#
#       price_plus_365 price_change Symbol                  Sector  \
# 0         138.250000     2.850006   NVDA              Technology
# 1           4.820000     0.620000    NGL               Utilities
# 2         429.130005    22.730011     HD  Consumer Discretionary
# 3         345.160004   126.309998   TSLA  Consumer Discretionary
# 4         315.079987    28.229980      V  Consumer Discretionary
# ...              ...          ...    ...                     ...
# 41312     156.649994    66.469994    LMT             Industrials
# 41313      64.886871    20.153503     DD             Industrials
# 41314      80.419998    13.419998     PG  Consumer Discretionary
# 41315      87.540001     4.239998    CAT             Industrials
# 41316      80.910004    16.890007     PG  Consumer Discretionary
#
#                                Industry                      Date  \
# 0                        Semiconductors                       NaT
# 1              Natural Gas Distribution                       NaT
# 2            RETAIL: Building Materials                       NaT
# 3                    Auto Manufacturing                       NaT
# 4                     Business Services                       NaT
# ...                                 ...                       ...
# 41312     Military/Government/Technical 2012-11-13 00:00:00+00:00
# 41313                   Major Chemicals 2012-09-13 00:00:00+00:00
# 41314           Package Goods/Cosmetics 2012-08-16 00:00:00+00:00
# 41315  Construction/Ag Equipment/Trucks 2012-07-26 00:00:00+00:00
# 41316           Package Goods/Cosmetics 2012-07-24 00:00:00+00:00
#
#                   Date_Plus_365 S&P500 Change (%)
# 0                           NaT               NaN
# 1                           NaT               NaN
# 2                           NaT               NaN
# 3                           NaT               NaN
# 4                           NaT               NaN
# ...                         ...               ...
# 41312 2013-11-13 00:00:00+00:00             29.64
# 41313 2013-09-13 00:00:00+00:00             15.62
# 41314 2013-08-16 00:00:00+00:00             16.98
# 41315 2013-07-26 00:00:00+00:00             24.38
# 41316 2013-07-24 00:00:00+00:00             25.98
#
# [41317 rows x 29 columns]

# %%
merged_trades['price_change_pct'] = (merged_trades['price_plus_365'] - merged_trades['price']) / merged_trades['price']*100
merged_trades['365Day_excess_return'] = merged_trades['price_change_pct'] - merged_trades['S&P500 Change (%)']

# %%
merged_trades.head()
# Out:
#   Ticker TickerType                                            Company  \
# 0   NVDA         ST                  NVIDIA CORPORATION - COMMON STOCK
# 1    NGL         ST  NGL ENERGY PARTNERS LP COMMON UNITS REPRESENTI...
# 2     HD         ST                                   HOME DEPOT, INC.
# 3   TSLA         ST                         TESLA, INC. - COMMON STOCK
# 4      V         ST                                          VISA INC.
#
#                      Traded Transaction      Trade_Size_USD Status  \
# 0 2024-11-01 00:00:00+00:00    Purchase    $1,001 - $15,000    NEW
# 1 2024-10-24 00:00:00+00:00        Sale  $50,001 - $100,000    NEW
# 2 2024-10-21 00:00:00+00:00    Purchase    $1,001 - $15,000    NEW
# 3 2024-10-21 00:00:00+00:00    Purchase    $1,001 - $15,000    NEW
# 4 2024-10-21 00:00:00+00:00    Purchase    $1,001 - $15,000    NEW
#
#                                Subholding Description  \
# 0                                 IRA ONE         NaN
# 1   EQUITABLE ADVISORS INVESTMENT ACCOUNT         NaN
# 2                                     NaN         NaN
# 3                                     NaN         NaN
# 4                                     NaN         NaN
#
#                          Name  ... price_plus_365 price_change Symbol  \
# 0               Pete Sessions  ...     138.250000     2.850006   NVDA
# 1               Mark Dr Green  ...       4.820000     0.620000    NGL
# 2  Marjorie Taylor Mrs Greene  ...     429.130005    22.730011     HD
# 3  Marjorie Taylor Mrs Greene  ...     345.160004   126.309998   TSLA
# 4  Marjorie Taylor Mrs Greene  ...     315.079987    28.229980      V
#
#                    Sector                    Industry Date Date_Plus_365  \
# 0              Technology              Semiconductors  NaT           NaT
# 1               Utilities    Natural Gas Distribution  NaT           NaT
# 2  Consumer Discretionary  RETAIL: Building Materials  NaT           NaT
# 3  Consumer Discretionary          Auto Manufacturing  NaT           NaT
# 4  Consumer Discretionary           Business Services  NaT           NaT
#
#    S&P500 Change (%) price_change_pct 365Day_excess_return
# 0                NaN         2.104879                  NaN
# 1                NaN        14.761914                  NaN
# 2                NaN         5.593015                  NaN
# 3                NaN        57.715327                  NaN
# 4                NaN         9.841373                  NaN
#
# [5 rows x 31 columns]

# %%
output_df = merged_trades
output_df = output_df.dropna(subset=['365Day_excess_return'])
output_df
# Out:
#       Ticker TickerType                                            Company  \
# 2313    CORP         ST  PIMCO INVESTMENT GRADE CORPORATE BOND INDEX EX...
# 2314     TMO         ST                       THERMO FISHER SCIENTIFIC INC
# 2315     CRT         ST                        CROSS TIMBERS ROYALTY TRUST
# 2316     HCA         ST                               HCA HEALTHCARE, INC.
# 2317    PANW         ST                           PALO ALTO NETWORKS, INC.
# ...      ...        ...                                                ...
# 41312    LMT        NaN                        LOCKHEED MARTIN CORPORATION
# 41313     DD      Stock        E. I. du Pont de Nemours and Company (NYSE)
# 41314     PG        NaN                           PROCTER & GAMBLE COMPANY
# 41315    CAT        NaN                                  CATERPILLAR, INC.
# 41316     PG        NaN                           PROCTER & GAMBLE COMPANY
#
#                          Traded Transaction    Trade_Size_USD Status  \
# 2313  2023-11-28 00:00:00+00:00        Sale  $1,001 - $15,000    NEW
# 2314  2023-11-28 00:00:00+00:00        Sale  $1,001 - $15,000    NEW
# 2315  2023-11-28 00:00:00+00:00    Purchase  $1,001 - $15,000    NEW
# 2316  2023-11-28 00:00:00+00:00        Sale  $1,001 - $15,000    NEW
# 2317  2023-11-28 00:00:00+00:00    Purchase  $1,001 - $15,000    NEW
# ...                         ...         ...               ...    ...
# 41312 2012-11-13 00:00:00+00:00        Sale  $1,001 - $15,000    NEW
# 41313 2012-09-13 00:00:00+00:00    Purchase  $1,001 - $15,000    New
# 41314 2012-08-16 00:00:00+00:00        Sale  $1,001 - $15,000    NEW
# 41315 2012-07-26 00:00:00+00:00    Purchase  $1,001 - $15,000    NEW
# 41316 2012-07-24 00:00:00+00:00        Sale  $1,001 - $15,000    NEW
#
#                                      Subholding  \
# 2313                                 UNITED IRA
# 2314    MORGAN STANLEY - SELECT UMA ACCOUNT # 1
# 2315                                        NaN
# 2316    MORGAN STANLEY - SELECT UMA ACCOUNT # 1
# 2317    MORGAN STANLEY - SELECT UMA ACCOUNT # 1
# ...                                         ...
# 41312                   BROKERAGE #1 - EDJ 2718
# 41313                                       NaN
# 41314                   BROKERAGE #1 - EDJ 2718
# 41315                    BROKERAGE #2 USAA 8425
# 41316                    BROKERAGE #2 USAA 8425
#
#                                              Description                 Name  \
# 2313   11/28/23 SOLD 383.695 SHARES OF PIMCO INVESTME...  Carol Devine Miller
# 2314                                                 NaN      Josh Gottheimer
# 2315                                                 NaN        Virginia Foxx
# 2316                                                 NaN      Josh Gottheimer
# 2317                                                 NaN      Josh Gottheimer
# ...                                                  ...                  ...
# 41312                                                NaN  Ms. Tammy Duckworth
# 41313                                                NaN    Carper, Thomas R.
# 41314                                                NaN  Ms. Tammy Duckworth
# 41315                                                NaN  Ms. Tammy Duckworth
# 41316                                                NaN  Ms. Tammy Duckworth
#
#        ... price_plus_365 price_change Symbol                  Sector  \
# 2313   ...      97.629997     3.919998    NaN                     NaN
# 2314   ...     529.630005    43.709991    TMO             Industrials
# 2315   ...      10.940000    -9.160001    CRT                  Energy
# 2316   ...     327.220001    80.570007    HCA             Health Care
# 2317   ...     387.820007   109.990021   PANW              Technology
# ...    ...            ...          ...    ...                     ...
# 41312  ...     156.649994    66.469994    LMT             Industrials
# 41313  ...      64.886871    20.153503     DD             Industrials
# 41314  ...      80.419998    13.419998     PG  Consumer Discretionary
# 41315  ...      87.540001     4.239998    CAT             Industrials
# 41316  ...      80.910004    16.890007     PG  Consumer Discretionary
#
#                                Industry                      Date  \
# 2313                                NaN 2023-11-28 00:00:00+00:00
# 2314    Industrial Machinery/Components 2023-11-28 00:00:00+00:00
# 2315               Oil & Gas Production 2023-11-28 00:00:00+00:00
# 2316        Hospital/Nursing Management 2023-11-28 00:00:00+00:00
# 2317      Computer peripheral equipment 2023-11-28 00:00:00+00:00
# ...                                 ...                       ...
# 41312     Military/Government/Technical 2012-11-13 00:00:00+00:00
# 41313                   Major Chemicals 2012-09-13 00:00:00+00:00
# 41314           Package Goods/Cosmetics 2012-08-16 00:00:00+00:00
# 41315  Construction/Ag Equipment/Trucks 2012-07-26 00:00:00+00:00
# 41316           Package Goods/Cosmetics 2012-07-24 00:00:00+00:00
#
#                   Date_Plus_365  S&P500 Change (%) price_change_pct  \
# 2313  2024-11-27 00:00:00+00:00              31.70         4.183116
# 2314  2024-11-27 00:00:00+00:00              31.70         8.995306
# 2315  2024-11-27 00:00:00+00:00              31.70       -45.572142
# 2316  2024-11-27 00:00:00+00:00              31.70        32.665724
# 2317  2024-11-27 00:00:00+00:00              31.70        39.588967
# ...                         ...                ...              ...
# 41312 2013-11-13 00:00:00+00:00              29.64        73.708132
# 41313 2013-09-13 00:00:00+00:00              15.62        45.052506
# 41314 2013-08-16 00:00:00+00:00              16.98        20.029848
# 41315 2013-07-26 00:00:00+00:00              24.38         5.090033
# 41316 2013-07-24 00:00:00+00:00              25.98        26.382393
#
#       365Day_excess_return
# 2313            -27.516884
# 2314            -22.704694
# 2315            -77.272142
# 2316              0.965724
# 2317              7.888967
# ...                    ...
# 41312            44.068132
# 41313            29.432506
# 41314             3.049848
# 41315           -19.289967
# 41316             0.402393
#
# [38821 rows x 31 columns]

# %%
# remove timezones
# output_df['Traded'] = output_df['Traded'].dt.tz_localize()
# output_df['Traded'] = output_df['Traded'].dt.date
output_df['Date'] = output_df['Date'].dt.date
output_df['Date_Plus_365'] = output_df['Date_Plus_365'].dt.date
# Store output df
output_df.to_excel('../data/qq_trade_df.xlsx',index=False)
# Out:
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\122401904.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_df['Date'] = output_df['Date'].dt.date
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\122401904.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_df['Date_Plus_365'] = output_df['Date_Plus_365'].dt.date

# %%
def get_congress_number(date):
    start_year = 1789  # Start year of the 1st Congress
    congress_number = ((date.year - start_year) // 2) + 1
    if date.month == 1 and date.day < 3:  # Adjust if before January 3
        congress_number -= 1
    return congress_number

output_df['congress']=output_df['Traded'].apply(get_congress_number)
# Out:
# C:\Users\Jerrin\AppData\Local\Temp\ipykernel_65464\640938495.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   output_df['congress']=output_df['Traded'].apply(get_congress_number)

# %%
output_df.to_excel('../data/qq_trade_df.xlsx',index=False)

# %%
output_df
